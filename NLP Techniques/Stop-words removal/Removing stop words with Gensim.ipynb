# %% [markdown]
# # Removing stop words with Gensim

# %% [markdown]
# The Gensim library is another extremely useful library for removing stop words from a string in Python.

# %%
from gensim.parsing.preprocessing import remove_stopwords

text = "hamza likes to play football, however he is not too fond of tennis."
filtered_sentence = remove_stopwords(text)

print("with stop words : \n",text) 
print('-_-')
print("without stop words : \n",filtered_sentence)
# Out:
# with stop words :
#  hamza likes to play football, however he is not too fond of tennis.
# -_-
# without stop words :
#  hamza likes play football, fond tennis.

# %% [markdown]
# ### Adding Stop Words to Default Gensim Stop Words List

# %%
from gensim.parsing.preprocessing import STOPWORDS
# nltk for word_tokenize
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize 

all_stopwords_gensim = STOPWORDS.union(set(['likes', 'play']))

text = "hamza likes to play football, however he is not too fond of tennis."
text_tokens = word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in all_stopwords_gensim]

print("with stop words : \n",text_tokens) 
print('-_-')
print("without stop words : \n",tokens_without_sw)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# with stop words :
#  ['hamza', 'likes', 'to', 'play', 'football', ',', 'however', 'he', 'is', 'not', 'too', 'fond', 'of', 'tennis', '.']
# -_-
# without stop words :
#  ['hamza', 'football', ',', 'fond', 'tennis', '.']
