# %% [markdown]
# # Lemmatization using SpaCy

# %%
import spacy

# load the core English language model
nlp = spacy.load('en_core_web_sm')

# %%
# input text

text = nlp(u'He was running and eating at same time')

for word in text:
    print(word.text,  word.lemma_)
# Out:
# He -PRON-
# was be
# running run
# and and
# eating eat
# at at
# same same
# time time
